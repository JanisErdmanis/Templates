# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
# %load_ext sympyprinting
import sympy as s

# %%
s.var('x y z')
# Out:
# (x, y, z)

# %%
zf = s.lambdify((x,y),x**2 + 2*y**2,'numpy')
zf2 = s.lambdify((x,y),x**2 + y**2,'numpy')
yf = s.lambdify((x,z),x,'numpy')

# %%
a = linspace(-5,5,70)
b = linspace(-5,5,70)
X,Y = meshgrid(a,b)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X,Y,zf(X,Y),alpha=0.3) #wireframe
ax.plot_surface(X,Y,zf2(X,Y),alpha=0.3,color='red') #wireframe

X,Z = meshgrid(a,linspace(0,70,70))
ax.plot_surface(X,yf(X,Y),Z,alpha=0.7,color='green') #wireframe

# %% [markdown]
# ### Reģiona vizualizācija
